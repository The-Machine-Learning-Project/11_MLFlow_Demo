# %% [markdown]
# ### Exporatory Data Analysis

# %% [markdown]
# ##### Notebook Setup

# %%
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Data Pull

# %%
data = pd.read_csv('../02_data/02_processed/credit_card_data_processed.csv')
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT_IND
# ...

# %% [markdown]
# ##### Data Profile

# %%
data.shape
# Out:
# (30000, 25)

# %%
data.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_1         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           30000 non-null  int64
#  1   LIMIT_BAL    30000 non-null  int64
#  2   SEX          30000 non-null  int64
#  3   EDUCATION    30000 non-null  int64
#  4   MARRIAGE     30000 non-null  int64
#  5   AGE          30000 non-null  int64
#  6   PAY_1        30000 non-null  int64
#  7   PAY_2        30000 non-null  int64
#  8   PAY_3        30000 non-null  int64
#  9   PAY_4        30000 non-null  int64
#  10  PAY_5        30000 non-null  int64
#  11  PAY_6        30000 non-null  int64
#  12  BILL_AMT1    30000 non-null  int64
#  13  BILL_AMT2    30000 non-null  int64
#  14  BILL_AMT3    30000 non-null  int64
#  15  BILL_AMT4    30000 non-null  int64
#  16  BILL_AMT5    30000 non-null  int64
#  17  BILL_AMT6    30000 non-null  int64
#  18  PAY_AMT1     30000 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# ID             0
# LIMIT_BAL      0
# SEX            0
# EDUCATION      0
# MARRIAGE       0
# AGE            0
# PAY_1          0
# PAY_2          0
# PAY_3          0
# PAY_4          0
# PAY_5          0
# PAY_6          0
# BILL_AMT1      0
# BILL_AMT2      0
# BILL_AMT3      0
# BILL_AMT4      0
# BILL_AMT5      0
# BILL_AMT6      0
# PAY_AMT1       0
# PAY_AMT2       0
# PAY_AMT3       0
# PAY_AMT4       0
# PAY_AMT5       0
# PAY_AMT6       0
# DEFAULT_IND    0
# dtype: int64

# %% [markdown]
# ##### Configure Parameters

# %%
X = [*data.columns][:-1]
y = [*data.columns][-1]

print(f"Predictors: Count: {len(X)} | {X}")
print(f"Target:                 ['{y}']")
# Out:
# Predictors: Count: 24 | ['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
# Target:                 ['DEFAULT_IND']

# %% [markdown]
# ##### Data Visualization

# %%
# Configure parameters
sns.set(style = 'ticks')


# Create sublots
fig, axes = plt.subplots(1, 2, figsize=(15, 5.5))

#Custom Colors
color_mapping = {1: '#FF922D', 0: '#0853A6'}

#  Subplot 1
sns.barplot(data = data, x = y, y = 'LIMIT_BAL', hue = y, palette = color_mapping, ax = axes[0])

# Subplot 2
sns.histplot(data = data, x = 'LIMIT_BAL', hue = y, palette = color_mapping, ax = axes[1])


# Display
plt.suptitle('Limit Balance by Default Indicator')
plt.tight_layout()
plt.show()

# %%
# Configure parameters
sns.set(rc = {'figure.figsize':(8,5.5)},
        style = 'ticks')

#Custom Colors
color_mapping = {1: '#FF922D', 0: '#0853A6'}

# Plot
sns.countplot(data = data, x = 'SEX', hue = y, palette = color_mapping)

# Display
plt.title('Sex by Defaut Indicator')
plt.tight_layout()
plt.show()

# %%
# Configure parameters
sns.set(rc = {'figure.figsize':(12,5.5)},
        style = 'ticks')

#Custom Colors
color_mapping = {1: '#FF922D', 0: '#0853A6'}

# Plot
sns.countplot(data = data, x = 'EDUCATION', hue = y, palette = color_mapping)

# Display
plt.title('Education by Defaut Indicator')
plt.tight_layout()
plt.show()

# %%
# Configure parameters
sns.set(rc = {'figure.figsize':(12,5.5)},
        style = 'ticks')

#Custom Colors
color_mapping = {1: '#FF922D', 0: '#0853A6'}

# Plot
sns.countplot(data = data, x = 'MARRIAGE', hue = y, palette = color_mapping)

# Display
plt.title('Marriage by Defaut Indicator')
plt.tight_layout()
plt.show()

# %%
# Configure parameters
sns.set(style = 'ticks')

# Create sublots
fig, axes = plt.subplots(1, 2, figsize=(15, 5.5))

#Custom Colors
color_mapping = {1: '#FF922D', 0: '#0853A6'}

#  Subplot 1
sns.barplot(data = data, x = y, y = 'AGE', hue = y, palette = color_mapping, ax = axes[0])

# Subplot 2
sns.histplot(data = data, x = 'AGE', hue = y, palette = color_mapping, ax = axes[1])


# Display
plt.suptitle('Age by Default Indicator')
plt.tight_layout()
plt.show()

# %%
# Configure parameters
sns.set(style = 'ticks')

# Create sublots
fig, axes = plt.subplots(2, 3, figsize=(15, 8))

#Custom Colors
color_mapping = {1: '#FF922D', 0: '#0853A6'}

# Subplots
for ax, col in zip(axes.flat, ['PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']): 
    sns.countplot(data = data, x = col, hue = y, palette = color_mapping, ax = ax)

# Display
plt.suptitle('Age by Default Indicator')
plt.tight_layout()
plt.show()

# %%
# Configure parameters
sns.set(style = 'ticks')

# Create sublots
fig, axes = plt.subplots(2, 3, figsize=(15, 8))

#Custom Colors
color_mapping = {1: '#FF922D', 0: '#0853A6'}

# Subplots
for ax, col in zip(axes.flat, ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']): 
    sns.histplot(data = data, x = col, hue = y, palette = color_mapping, bins = 20, ax = ax)

# Display
plt.suptitle('Bill Amount by Default Indicator')
plt.tight_layout()
plt.show()

# %%
# Configure parameters
sns.set(style = 'ticks')

# Create sublots
fig, axes = plt.subplots(2, 3, figsize=(15, 8))

#Custom Colors
color_mapping = {1: '#FF922D', 0: '#0853A6'}

# Subplots
for ax, col in zip(axes.flat, ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']): 
    sns.histplot(data = data, x = col, hue = y, palette = color_mapping, bins = 20, ax = ax)

# Display
plt.suptitle('Payment Amount by Default Indicator')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Correlation

# %%
figure = plt.figure(figsize=(20,15))
sns.heatmap(
    data = data.corr(), annot=True, fmt = '0.1f', linewidths=1,cmap='crest'
)

plt.show()
